# %% [markdown]
# ## Q1. What are the three measures of central tendency?

# %% [markdown]
# ## There are three main measures of central tendency: mode. median. mean.

# %% [markdown]
# ## Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?

# %% [markdown]
# ## The mean is the average where the sum of all the numbers is divided by the total number of numbers, whereas the median is the middle value in the list of given numbers numerically ordered from smallest to biggest and mode is the value of the number which occurs most often in the list.

# %%
## example of measure of central tendancy

# %%
import numpy as np

# %%
weights=[78,45,76,78,90,45,67,86]

# %%
np.mean(weights)
# Out:
# 70.625

# %%
np.median(weights)
# Out:
# 77.0

# %%
from scipy import stats

# %%
stats.mode(weights)
# Out:
# /tmp/ipykernel_77/4197893964.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(weights)
# ModeResult(mode=array([45]), count=array([2]))

# %% [markdown]
# ## Q3. Measure the three measures of central tendency for the given height data:

# %%
D=[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
np.mean(D)
# Out:
# 177.01875

# %%
np.median(D)
# Out:
# 177.0

# %%
stats.mode(D)
# Out:
# /tmp/ipykernel_77/3748789018.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(D)
# ModeResult(mode=array([177.]), count=array([3]))

# %% [markdown]
# ## Q4. Find the standard deviation for the given data:

# %%
dt=[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
std=np.std(dt)

# %%
std
# Out:
# 1.7885814036548633

# %% [markdown]
# ## Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example.

# %% [markdown]
# ## Range, variance, and standard deviation all measure the spread or variability of a data set in different ways. The range is easy to calculate—it's the difference between the largest and smallest data points in a set. Standard deviation is the square root of the variance

# %%
import pandas as pd
data=[10,12,13],[23,63,32],[34,32,54]

# %%
data
# Out:
# ([10, 12, 13], [23, 63, 32], [34, 32, 54])

# %%
df=pd.DataFrame(data,columns=['A','B','C'])

# %%
df
# Out:
#     A   B   C
# 0  10  12  13
# 1  23  63  32
# 2  34  32  54

# %%
df.mean()
# Out:
# A    22.333333
# B    35.666667
# C    33.000000
# dtype: float64

# %% [markdown]
# df.var()

# %%
df.std()
# Out:
# A    12.013881
# B    25.696952
# C    20.518285
# dtype: float64

# %% [markdown]
# ## Range
# ## The range of the data is given as the difference between the maximum and the minimum values of the observations in the data. For example, let’s say we have data on the number of customers walking in the store in a week.
#
#
# ##  Variance
# ## The variance of the data is given by measuring the distance of the observed values from the mean of the distribution.

# %%
list=[3, 5, 5, 6, 7, 9, 10]

# %%
np.mean(list)
# Out:
# 6.428571428571429

# %%
np.var(list)
# Out:
# 5.102040816326531

# %%
np.std(list)
# Out:
# 2.2587697572631282

# %% [markdown]
# ![dispersion.png](attachment:578c380d-fe5a-45db-8488-27900ee54dd6.png)

# %% [markdown]
# ## Q6. What is a Venn diagram?

# %% [markdown]
# ## A Venn diagram uses overlapping circles or other shapes to illustrate the logical relationships between two or more sets of items. Often, they serve to graphically organize things, highlighting how the items are similar and different.

# %% [markdown]
# ![venn.png](attachment:f15cf0f2-8b87-43df-a907-a1b4c5bca83b.png)

# %% [markdown]
# ## Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
# ## (i) A intersection B
# ## (ii) A ⋃ B

# %%
A = {2,3,4,5,6,7}
B = {0,2,6,8,10}  
# union 
print("Union :", A | B) 
  
# intersection 
print("Intersection :", A & B)
# Out:
# Union : {0, 2, 3, 4, 5, 6, 7, 8, 10}
# Intersection : {2, 6}

# %% [markdown]
# ## Q8. What do you understand about skewness in data?

# %% [markdown]
# ## Skewness is a measurement of the distortion of symmetrical distribution or asymmetry in a data set. Skewness is demonstrated on a bell curve when data points are not distributed symmetrically to the left and right sides of the median on a bell curve.

# %% [markdown]
# ## Q9. If a data is right skewed then what will be the position of median with respect to mean?

# %% [markdown]
# ## If the distribution of data is skewed to the right, the mode is often less than the median, which is less than the mean.

# %% [markdown]
# ![skewed.png](attachment:c29fa7ba-4801-4866-8b59-49e7a8be6cab.png)

# %% [markdown]
# ## Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?

# %% [markdown]
# ## Both covariance and correlation measure the relationship and the dependency between two variables. Covariance indicates the direction of the linear relationship between variables. Correlation measures both the strength and direction of the linear relationship between two variables. Correlation values are standardized.

# %% [markdown]
# ## In statistical analysis, Covariance indicates whether two variables fluctuate in the same (positive covariance) or opposite direction (negative covariance). The numerical value of covariance has no importance; only the sign is relevant.

# %% [markdown]
# ## Q11. What is the formula for calculating the sample mean? Provide an example calculation for a dataset.

# %% [markdown]
# ## The general formula for calculating the sample mean is given by x̄ = ( Σ xi ) / n. Here, x̄ represents the sample mean, xi refers all X sample values and n stands for the number of sample terms in the data set.

# %%
terms = [60 , 57 , 109 , 50 , 276]
## By using formula
s=sum(terms)
l=len(terms)

# %%
s
# Out:
# 552

# %%
l
# Out:
# 5

# %%
mean=s / l

# %%
mean
# Out:
# 110.4

# %%
## by using mean function
np.mean(terms)
# Out:
# 110.4

# %% [markdown]
# ## Q12. For a normal distribution data what is the relationship between its measure of central tendency?

# %% [markdown]
# ## In a normal distribution, data is symmetrically distributed with no skew. Most values cluster around a central region, with values tapering off as they go further away from the center. The mean, mode and median are exactly the same in a normal distribution.

# %% [markdown]
# ## Q13. How is covariance different from correlation?

# %% [markdown]
# ## Covariance tells us the direction of the relationship between two variables, while correlation provides an indication as to how strong the relationship between the two variables is, in addition to the direction of correlated variables. Correlation values range from +1 to -1.

# %% [markdown]
# ## Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.

# %% [markdown]
# ## Mean: Outliers can pull the mean towards their extreme values. If there are outliers with large values, the mean can be inflated, while outliers with small values can lower the mean.
# ## Median: The median is less affected by outliers compared to the mean.  It represents the middle value, so outliers have less impact unless they are close to the median and significantly change the order of values.
# ## Mode: The mode is the most frequent value. Outliers do not directly affect the mode unless they appear frequently and change the overall distribution of values.

# %%
import scipy.stats as stat
import pylab
import numpy as np

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.mean()
# Out:
# /tmp/ipykernel_441/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
df.median()
# Out:
# /tmp/ipykernel_441/530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
df.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.0           1.4          0.2      setosa
# 1           NaN          NaN           1.5          NaN  versicolor
# 2           NaN          NaN           NaN          NaN   virginica

# %%
import matplotlib.pyplot as plt

# %%
def plot_data(df, feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(df[feature], kde=True)
    plt.subplot(1,2,2)
    stat.probplot(df[feature], dist='norm', plot=pylab)
    plt.show()

# %%
plot_data(df,'sepal_width')
