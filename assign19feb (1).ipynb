# %% [markdown]
# ## Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# ## Answer

# %% [markdown]
# ## Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.

# %% [markdown]
# ## Advantages of using Flask framework are:
# ## There is a built-in development server and a fast debugger provided.
# ## Lightweight.
# ## Support Secure cookies.
# ## Templating using Jinja2.
# ## Request dispatching using REST.
# ## Support for unit testing is built-in.

# %% [markdown]
# ## Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ## Answer

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "'Hello World!!'"
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (7).png](attachment:ea3482e1-1229-4ff4-a9d9-b73979742870.png)

# %% [markdown]
# ## Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ## Answer

# %% [markdown]
# ## App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL.

# %% [markdown]
# ## App routing is the technique used to map the specific URL with the associated function intended to perform some task. The Latest Web frameworks use the routing technique to help users remember application URLs. It is helpful to access the desired page directly without navigating from the home page.

# %% [markdown]
# ## Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
#
# ## Company Name: ABC Corporation
#
# ## Location: India
#
# ## Contact Detail: 999-999-9999

# %% [markdown]
# ## Answer

# %% [markdown]
# from flask import Flask
# from flask import request
#
# app = Flask(__name__)
#
# @app.route("/welcome")
# def welcome():
#     return "Welcome to ABC Corporation"
#
#
# @app.route("/")
# def welcome_corporation():
#     return ("Company Name: ABC Corporation <br>"
#         "Location: India <br>"
#         "Contact Detail: 999-999-9999")
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (10).png](attachment:626b3382-bd3b-4c9e-b6d5-8632bdee9337.png)

# %% [markdown]
# ![Screenshot (11).png](attachment:7640fd6b-c5dc-4245-a2e2-dd40a53b0bf4.png)

# %% [markdown]
# ## Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# ## Answer

# %% [markdown]
# ## Flask url_for() method
# ## The url_for() method, is used to prepare a URL, for a function dynamically, such that, changing URLs, in the application, is avoided. It accepts, the name of the view function, as the first argument, and, any number of keywords, to be sent(to the view function), as the second argument.

# %% [markdown]
# from flask import Flask, redirect, url_for
# app = Flask(__name__)
#
# @app.route('/admin')
# def hello_admin():
#    return 'Hello Admin'
#
# @app.route('/guest/<guest>')
# def hello_guest(guest):
#    return 'Hello %s as Guest' % guest
#
# @app.route('/user/<name>')
# def hello_user(name):
#    if name =='admin':
#       return redirect(url_for('hello_admin'))
#    else:
#       return redirect(url_for('hello_guest',guest = name))
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (13).png](attachment:8fa3bbb6-a854-4544-913d-20e48e77b295.png)

# %% [markdown]
# ![Screenshot (14).png](attachment:3f7b5e41-f89c-4034-ade0-d0b129c4cf8f.png)
